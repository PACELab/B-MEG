# %%
import os
import sys
import numpy as np
import pandas as pd
import pickle

# %%
sample_rows = 4000000

# %%
def meanNorm(X):
    dfx = []
    col = X.columns.tolist()
    
    for ix,r in X.iterrows():
        r = pd.Series(r)
        val = r.values.tolist()
        s = sum(val)

        rw = [i/s for i in val]

        dfx.append(rw)
    X = pd.DataFrame(dfx, columns = col)
    return X

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(out.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()

# %%
n0 = pd.read_csv("../data/tracing-data/hotel-reservation/0_frontend.csv")
n0 = n0.loc[:, ["0_frontend", "1_search", "2_geo", "3_rate", "4_profile", "5_locale"]]
n0 = meanNorm(n0)
n0['label'] = 0

n1 = pd.read_csv("../data/tracing-data/hotel-reservation/1_search.csv")
n1 = n1.loc[:, ["0_frontend", "1_search", "2_geo", "3_rate", "4_profile", "5_locale"]]
n1 = meanNorm(n1)
n1['label'] = 1

n2 = pd.read_csv("../data/tracing-data/hotel-reservation/2_geo.csv")
n2 = n2.loc[:, ["0_frontend", "1_search", "2_geo", "3_rate", "4_profile", "5_locale"]]
n2 = meanNorm(n2)
n2['label'] = 2


n3 = pd.read_csv("../data/tracing-data/hotel-reservation/3_rate.csv")
n3 = n3.loc[:, ["0_frontend", "1_search", "2_geo", "3_rate", "4_profile", "5_locale"]]
n3 = meanNorm(n3)
n3['label'] = 3

n4 = pd.read_csv("../data/tracing-data/hotel-reservation/4_profile.csv")
n4 = n4.loc[:, ["0_frontend", "1_search", "2_geo", "3_rate", "4_profile", "5_locale"]]
n4 = meanNorm(n4)
n4['label'] = 4

n5 = pd.read_csv("../data/tracing-data/hotel-reservation/5_locale.csv")
n5 = n5.loc[:, ["0_frontend", "1_search", "2_geo", "3_rate", "4_profile", "5_locale"]]
n5 = meanNorm(n5)
n5['label'] = 5

n6 = pd.read_csv("../data/tracing-data/hotel-reservation/no-interference.csv")
n6 = n6.loc[:, ["0_frontend", "1_search", "2_geo", "3_rate", "4_profile", "5_locale"]]
n6 = meanNorm(n6)
n6['label'] = -1

# %%
dat = pd.concat([n0, n1, n2, n3, n4, n5, n6])
print(dat.shape)

filehandler = open("../data/full_data/hotel_reservation.pkl","wb")
pickle.dump(dat, filehandler)
filehandler.close()
tot_rows = dat.shape[0]
# Out:
# (5530000, 7)

# %%
n0_sample = n0.sample(n = int(n0.shape[0]*sample_rows/tot_rows))
n1_sample = n1.sample(n = int(n1.shape[0]*sample_rows/tot_rows))
n2_sample = n2.sample(n = int(n2.shape[0]*sample_rows/tot_rows))
n3_sample = n3.sample(n = int(n3.shape[0]*sample_rows/tot_rows))
n4_sample = n4.sample(n = int(n4.shape[0]*sample_rows/tot_rows))
n5_sample = n5.sample(n = int(n5.shape[0]*sample_rows/tot_rows))
n6_sample = n6.sample(n = int(n6.shape[0]*sample_rows/tot_rows))

dat_sample = pd.concat([n0_sample, n1_sample, n2_sample, n3_sample, n4_sample, n5_sample, n6_sample])
print(dat_sample.shape)
# Out:
# (3999996, 7)

# %%
filehandler = open("../data/sample_data/hotel_reservation_sample.pkl","wb")
pickle.dump(dat_sample, filehandler)
filehandler.close()

# %%
dat = pd.concat([n0, n1, n2, n3, n4, n5])
print(dat.shape)

filehandler = open("../data/full_data/hotel_reservation_only_bottlenecks.pkl","wb")
pickle.dump(dat, filehandler)
filehandler.close()
tot_rows = dat.shape[0]
# Out:
# (4740000, 7)

# %%
n0_sample = n0.sample(n = int(n0.shape[0]*sample_rows/tot_rows))
n1_sample = n1.sample(n = int(n1.shape[0]*sample_rows/tot_rows))
n2_sample = n2.sample(n = int(n2.shape[0]*sample_rows/tot_rows))
n3_sample = n3.sample(n = int(n3.shape[0]*sample_rows/tot_rows))
n4_sample = n4.sample(n = int(n4.shape[0]*sample_rows/tot_rows))
n5_sample = n5.sample(n = int(n5.shape[0]*sample_rows/tot_rows))


dat_sample = pd.concat([n0_sample, n1_sample, n2_sample, n3_sample, n4_sample, n5_sample])
print(dat_sample.shape)
# Out:
# (3999996, 7)

# %%
filehandler = open("../data/sample_data/hotel_reservation_only_bottlenecks_sample.pkl","wb")
pickle.dump(dat_sample, filehandler)
filehandler.close()

# %%
n0 = pd.read_csv("../data/tracing-data/media-service/0_nginx_compose-review.csv")
n0 = n0.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n0 = meanNorm(n0)
n0['label'] = 0

n1 = pd.read_csv("../data/tracing-data/media-service/1_uniqueid.csv")
n1 = n1.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n1 = meanNorm(n1)
n1['label'] = 1

n2 = pd.read_csv("../data/tracing-data/media-service/2_rating.csv")
n2 = n2.loc[:,["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n2 = meanNorm(n2)
n2['label'] = 2


n3 = pd.read_csv("../data/tracing-data/media-service/3_movieid.csv")
n3 = n3.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n3 = meanNorm(n3)
n3['label'] = 3


n4 = pd.read_csv("../data/tracing-data/media-service/4_userreview_uniqueid.csv")
n4 = n4.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n4 = meanNorm(n4)
n4['label'] = 4


n5 = pd.read_csv("../data/tracing-data/media-service/5_userreview_rating.csv")
n5 = n5.loc[:,["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n5 = meanNorm(n5)
n5['label'] = 5


n6 = pd.read_csv("../data/tracing-data/media-service/6_userreview_movieid.csv")
n6 = n6.loc[:,["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n6 = meanNorm(n6)
n6['label'] = 6


n7 = pd.read_csv("../data/tracing-data/media-service/7_composereview_uniqueid.csv")
n7 = n7.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n7 = meanNorm(n7)
n7['label'] = 7


n8 = pd.read_csv("../data/tracing-data/media-service/8_composereview_rating.csv")
n8 = n8.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n8 = meanNorm(n8)
n8['label'] = 8

n9 = pd.read_csv("../data/tracing-data/media-service/9_composereview_movieid.csv")
n9 = n9.loc[:,["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n9 = meanNorm(n9)
n9['label'] = 9

n10 = pd.read_csv("../data/tracing-data/media-service/10_movie_review_uniqueid.csv")
n10 = n10.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n10 = meanNorm(n10)
n10['label'] = 10


n11 = pd.read_csv("../data/tracing-data/media-service/11_movie_review_rating.csv")
n11 = n11.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n11 = meanNorm(n11)
n11['label'] = 11


n12 = pd.read_csv("../data/tracing-data/media-service/12_movie_review_movieid.csv")
n12 = n12.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n12 = meanNorm(n12)
n12['label'] = 12


n13 = pd.read_csv("../data/tracing-data/media-service/13_reviewstorage_uniqueid.csv")
n13 = n13.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n13 = meanNorm(n13)
n13['label'] = 13


n14 = pd.read_csv("../data/tracing-data/media-service/14_reviewstorage_rating.csv")
n14 = n14.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n14 = meanNorm(n14)
n14['label'] = 14


n15 = pd.read_csv("../data/tracing-data/media-service/15_reviewstorage_movieid.csv")
n15 = n15.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n15 = meanNorm(n15)
n15['label'] = 15


n16 = pd.read_csv("../data/tracing-data/media-service/16_redis_uniqueid.csv")
n16 = n16.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n16 = meanNorm(n16)
n16['label'] = 16


n17 = pd.read_csv("../data/tracing-data/media-service/17_redis_rating.csv")
n17 = n17.loc[:,["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n17 = meanNorm(n17)
n17['label'] = 17


n18 = pd.read_csv("../data/tracing-data/media-service/18_redis_movieid.csv")
n18 = n18.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n18 = meanNorm(n18)
n18['label'] = 18


n19 = pd.read_csv("../data/tracing-data/media-service/no-interference.csv")
n19 = n19.loc[:, ["0_nginx_compose-review", "1_uniqueid", "2_rating", "3_movieid", "4_userreview_uniqueid", "5_userreview_rating",
                "6_userreview_movieid", "7_composereview_uniqueid", "8_composereview_rating", "9_composereview_movieid", 
                "10_movie_review_uniqueid", "11_movie_review_rating", "12_movie_review_movieid", "13_reviewstorage_uniqueid",
                "14_reviewstorage_rating", "15_reviewstorage_movieid", "16_redis_uniqueid", "17_redis_rating", 
                "18_redis_movieid"]]
n19 = meanNorm(n19)
n19['label'] = -1

# %%
dat = pd.concat([n0, n1, n2, n3, n4, n5, n6, n7, n8, n9, n10, n11, n12, n13, n14, n15, n16, n17, n18, n19])
print(dat.shape)

filehandler = open("../data/full_data/media_service.pkl","wb")
pickle.dump(dat, filehandler)
filehandler.close()
tot_rows = dat.shape[0]
# Out:
# (15800000, 20)

# %%
n0_sample = n0.sample(n = int(n0.shape[0]*sample_rows/tot_rows))
n1_sample = n1.sample(n = int(n1.shape[0]*sample_rows/tot_rows))
n2_sample = n2.sample(n = int(n2.shape[0]*sample_rows/tot_rows))
n3_sample = n3.sample(n = int(n3.shape[0]*sample_rows/tot_rows))
n4_sample = n4.sample(n = int(n4.shape[0]*sample_rows/tot_rows))
n5_sample = n5.sample(n = int(n5.shape[0]*sample_rows/tot_rows))
n6_sample = n6.sample(n = int(n6.shape[0]*sample_rows/tot_rows))
n7_sample = n9.sample(n = int(n7.shape[0]*sample_rows/tot_rows))
n8_sample = n8.sample(n = int(n8.shape[0]*sample_rows/tot_rows))
n9_sample = n9.sample(n = int(n9.shape[0]*sample_rows/tot_rows))
n10_sample = n10.sample(n = int(n10.shape[0]*sample_rows/tot_rows))
n11_sample = n11.sample(n = int(n11.shape[0]*sample_rows/tot_rows))
n12_sample = n12.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n13_sample = n13.sample(n = int(n13.shape[0]*sample_rows/tot_rows))
n14_sample = n14.sample(n = int(n14.shape[0]*sample_rows/tot_rows))
n15_sample = n15.sample(n = int(n15.shape[0]*sample_rows/tot_rows))
n16_sample = n16.sample(n = int(n16.shape[0]*sample_rows/tot_rows))
n17_sample = n17.sample(n = int(n17.shape[0]*sample_rows/tot_rows))
n18_sample = n18.sample(n = int(n18.shape[0]*sample_rows/tot_rows))
n19_sample = n19.sample(n = int(n19.shape[0]*sample_rows/tot_rows))

dat_sample = pd.concat([n0_sample, n1_sample, n2_sample, n3_sample, n4_sample, n5_sample, n6_sample,
                        n7_sample, n8_sample, n9_sample, n10_sample, n11_sample, n12_sample, n13_sample,
                        n15_sample, n16_sample, n17_sample, n18_sample, n19_sample])
print(dat_sample.shape)
# Out:
# (3800000, 20)

# %%
filehandler = open("../data/sample_data/media_service_sample.pkl","wb")
pickle.dump(dat_sample, filehandler)
filehandler.close()

# %%
dat = pd.concat([n0, n1, n2, n3, n4, n5, n6, n8, n9, n10, n11, n12, n13, n14, n15, n16, n18])
print(dat.shape)

filehandler = open("../data/full_data/media_service_only_bottlenecks.pkl","wb")
pickle.dump(dat, filehandler)
filehandler.close()
tot_rows = dat.shape[0]
# Out:
# (13430000, 20)

# %%
n0_sample = n0.sample(n = int(n0.shape[0]*sample_rows/tot_rows))
n1_sample = n1.sample(n = int(n1.shape[0]*sample_rows/tot_rows))
n2_sample = n2.sample(n = int(n2.shape[0]*sample_rows/tot_rows))
n3_sample = n3.sample(n = int(n3.shape[0]*sample_rows/tot_rows))
n4_sample = n4.sample(n = int(n4.shape[0]*sample_rows/tot_rows))
n5_sample = n5.sample(n = int(n5.shape[0]*sample_rows/tot_rows))
n6_sample = n6.sample(n = int(n6.shape[0]*sample_rows/tot_rows))
n7_sample = n9.sample(n = int(n7.shape[0]*sample_rows/tot_rows))
n8_sample = n8.sample(n = int(n8.shape[0]*sample_rows/tot_rows))
n9_sample = n9.sample(n = int(n9.shape[0]*sample_rows/tot_rows))
n10_sample = n10.sample(n = int(n10.shape[0]*sample_rows/tot_rows))
n11_sample = n11.sample(n = int(n11.shape[0]*sample_rows/tot_rows))
n12_sample = n12.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n13_sample = n13.sample(n = int(n13.shape[0]*sample_rows/tot_rows))
n14_sample = n14.sample(n = int(n14.shape[0]*sample_rows/tot_rows))
n15_sample = n15.sample(n = int(n15.shape[0]*sample_rows/tot_rows))
n16_sample = n16.sample(n = int(n16.shape[0]*sample_rows/tot_rows))
n17_sample = n17.sample(n = int(n17.shape[0]*sample_rows/tot_rows))
n18_sample = n18.sample(n = int(n18.shape[0]*sample_rows/tot_rows))

dat_sample = pd.concat([n0_sample, n1_sample, n2_sample, n3_sample, n4_sample, n5_sample, n6_sample,
                        n7_sample, n8_sample, n9_sample, n10_sample, n11_sample, n12_sample, n13_sample,
                        n15_sample, n16_sample, n17_sample, n18_sample])
print(dat_sample.shape)
# Out:
# (4235292, 20)

# %%
filehandler = open("../data/sample_data/media_service_only_bottlenecks_sample.pkl","wb")
pickle.dump(dat_sample, filehandler)
filehandler.close()

# %%
n0 = pd.read_csv("../data/tracing-data/ticket-booking/0_gateway.csv")
n0 = n0.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n0 = meanNorm(n0)
n0['label'] = 0

n1 = pd.read_csv("../data/tracing-data/ticket-booking/1_ticket_reserve.csv")
n1 = n1.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n1 = meanNorm(n1)
n1['label'] = 1

n2 = pd.read_csv("../data/tracing-data/ticket-booking/2_ticket_explore.csv")
n2 = n2.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n2 = meanNorm(n2)
n2['label'] = 2


n3 = pd.read_csv("../data/tracing-data/ticket-booking/3_security.csv")
n3 = n3.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n3 = meanNorm(n3)
n3['label'] = 3


n4 = pd.read_csv("../data/tracing-data/ticket-booking/4_ticket_info.csv")
n4 = n4.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n4 = meanNorm(n4)
n4['label'] = 4


n5 = pd.read_csv("../data/tracing-data/ticket-booking/5_order.csv")
n5 = n5.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n5 = meanNorm(n5)
n5['label'] = 5


n6 = pd.read_csv("../data/tracing-data/ticket-booking/6_basic_info.csv")
n6 = n6.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n6 = meanNorm(n6)
n6['label'] = 6


n7 = pd.read_csv("../data/tracing-data/ticket-booking/7_config.csv")
n7 = n7.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n7 = meanNorm(n7)
n7['label'] = 7


n8 = pd.read_csv("../data/tracing-data/ticket-booking/8_station.csv")
n8 = n8.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n8 = meanNorm(n8)
n8['label'] = 8

n9 = pd.read_csv("../data/tracing-data/ticket-booking/9_train.csv")
n9 = n9.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n9 = meanNorm(n9)
n9['label'] = 9

n10 = pd.read_csv("../data/tracing-data/ticket-booking/10_contact.csv")
n10 = n10.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n10 = meanNorm(n10)
n10['label'] = 10


n11 = pd.read_csv("../data/tracing-data/ticket-booking/11_price.csv")
n11 = n11.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n11 = meanNorm(n11)
n11['label'] = 11


n12 = pd.read_csv("../data/tracing-data/ticket-booking/no-interference.csv")
n12 = n12.loc[:, ["0_gateway", "1_ticket_reserve", "2_ticket_explore", "3_security", "4_ticket_info", "5_order",
               "6_basic_info", "7_config", "8_station", "9_train", "10_contact", "11_price"]]
n12 = meanNorm(n12)
n12['label'] = -1

# %%
dat = pd.concat([n0, n1, n2, n3, n4, n5, n6, n7, n8, n9, n10, n11, n12])
print(dat.shape)

filehandler = open("../data/full_data/ticket_booking.pkl","wb")
pickle.dump(dat, filehandler)
filehandler.close()
tot_rows = dat.shape[0]
# Out:
# (10270000, 13)

# %%
n0_sample = n0.sample(n = int(n0.shape[0]*sample_rows/tot_rows))
n1_sample = n1.sample(n = int(n1.shape[0]*sample_rows/tot_rows))
n2_sample = n2.sample(n = int(n2.shape[0]*sample_rows/tot_rows))
n3_sample = n3.sample(n = int(n3.shape[0]*sample_rows/tot_rows))
n4_sample = n4.sample(n = int(n4.shape[0]*sample_rows/tot_rows))
n5_sample = n5.sample(n = int(n5.shape[0]*sample_rows/tot_rows))
n6_sample = n6.sample(n = int(n6.shape[0]*sample_rows/tot_rows))
n7_sample = n7.sample(n = int(n7.shape[0]*sample_rows/tot_rows))
n8_sample = n8.sample(n = int(n8.shape[0]*sample_rows/tot_rows))
n9_sample = n9.sample(n = int(n9.shape[0]*sample_rows/tot_rows))
n10_sample = n10.sample(n = int(n10.shape[0]*sample_rows/tot_rows))
n11_sample = n11.sample(n = int(n11.shape[0]*sample_rows/tot_rows))
n12_sample = n12.sample(n = int(n12.shape[0]*sample_rows/tot_rows))

dat_sample = pd.concat([n0_sample, n1_sample, n2_sample, n3_sample, n4_sample, n5_sample,
                       n6_sample, n7_sample, n8_sample, n9_sample, n10_sample, n11_sample, n12_sample])
print(dat_sample.shape)
# Out:
# (3999996, 13)

# %%
filehandler = open("../data/sample_data/ticket_booking_sample.pkl","wb")
pickle.dump(dat_sample, filehandler)
filehandler.close()

# %%
dat = pd.concat([n0, n1, n2, n3, n4, n5, n6, n7, n8, n9, n10, n11, n12])
print(dat.shape)

filehandler = open("../data/full_data/ticket_booking_only_bottlenecks.pkl","wb")
pickle.dump(dat, filehandler)
filehandler.close()
tot_rows = dat.shape[0]
# Out:
# (10270000, 13)

# %%
n0_sample = n0.sample(n = int(n0.shape[0]*sample_rows/tot_rows))
n1_sample = n1.sample(n = int(n1.shape[0]*sample_rows/tot_rows))
n2_sample = n2.sample(n = int(n2.shape[0]*sample_rows/tot_rows))
n3_sample = n3.sample(n = int(n3.shape[0]*sample_rows/tot_rows))
n4_sample = n4.sample(n = int(n4.shape[0]*sample_rows/tot_rows))
n5_sample = n5.sample(n = int(n5.shape[0]*sample_rows/tot_rows))
n6_sample = n6.sample(n = int(n6.shape[0]*sample_rows/tot_rows))
n7_sample = n7.sample(n = int(n7.shape[0]*sample_rows/tot_rows))
n8_sample = n8.sample(n = int(n8.shape[0]*sample_rows/tot_rows))
n9_sample = n9.sample(n = int(n9.shape[0]*sample_rows/tot_rows))
n10_sample = n10.sample(n = int(n10.shape[0]*sample_rows/tot_rows))
n11_sample = n11.sample(n = int(n11.shape[0]*sample_rows/tot_rows))


dat_sample = pd.concat([n0_sample, n1_sample, n2_sample, n3_sample, n4_sample, n5_sample,
                       n6_sample, n7_sample, n8_sample, n9_sample, n10_sample, n11_sample])
print(dat_sample.shape)
# Out:
# (3692304, 13)

# %%
filehandler = open("../data/sample_data/ticket_booking_only_bottlenecks_sample.pkl","wb")
pickle.dump(dat_sample, filehandler)
filehandler.close()

# %%
n1 = pd.read_csv("../data/tracing-data/social-network/1_nginx_compose-post.csv")
n1 = n1.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n1 = meanNorm(n1)
n1['label'] = 1

n2 = pd.read_csv("../data/tracing-data/social-network/2_mediaservice_upload.csv")
n2 = n2.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n2 = meanNorm(n2)
n2['label'] = 2

n3 = pd.read_csv("../data/tracing-data/social-network/3_userservice_upload.csv")
n3 = n3.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n3 = meanNorm(n3)
n3['label'] = 3

n4 = pd.read_csv("../data/tracing-data/social-network/4_textservice_upload.csv")
n4 = n4.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n4 = meanNorm(n4)
n4['label'] = 4


n5 = pd.read_csv("../data/tracing-data/social-network/5_uniqueid_upload.csv")
n5 = n5.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n5 = meanNorm(n5)
n5['label'] = 5

n6 = pd.read_csv("../data/tracing-data/social-network/6_composepost_uploadmedia.csv")
n6 = n6.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n6 = meanNorm(n6)
n6['label'] = 6

n7 = pd.read_csv("../data/tracing-data/social-network/7_composepost_uploadcreator.csv")
n7 = n7.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n7 = meanNorm(n7)
n7['label'] = 7

n8 = pd.read_csv("../data/tracing-data/social-network/8_urlservice_upload.csv")
n8 = n8.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n8 = meanNorm(n8)
n8['label'] = 8

n9 = pd.read_csv("../data/tracing-data/social-network/9_usermentionservice_upload.csv")
n9 = n9.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n9 = meanNorm(n9)
n9['label'] = 9

n10 = pd.read_csv("../data/tracing-data/social-network/10_composepost_uploadtext.csv")
n10 = n10.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n10 = meanNorm(n10)
n10['label'] = 10

n11 = pd.read_csv("../data/tracing-data/social-network/11_composepost_uploaduniqueid.csv")
n11 = n11.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n11 = meanNorm(n11)
n11['label'] = 11

n12 = pd.read_csv("../data/tracing-data/social-network/12_composepost_uploadurl.csv")
n12 = n12.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n12 = meanNorm(n12)
n12['label'] = 12

n13 = pd.read_csv("../data/tracing-data/social-network/13_composepost_uploadusermention.csv")
n13 = n13.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n13 = meanNorm(n13)
n13['label'] = 13

n14 = pd.read_csv("../data/tracing-data/social-network/14_poststorage_storepost_media.csv")
n14 = n14.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n14 = meanNorm(n14)
n14['label'] = 14

n15 = pd.read_csv("../data/tracing-data/social-network/15_usertimeline_write_media.csv")
n15 = n15.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n15 = meanNorm(n15)
n15['label'] = 15

n16 = pd.read_csv("../data/tracing-data/social-network/16_redishashset_update_media.csv")
n16 = n16.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n16 = meanNorm(n16)
n16['label'] = 16

n17 = pd.read_csv("../data/tracing-data/social-network/17_poststorage_storepost_text.csv")
n17 = n17.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n17 = meanNorm(n17)
n17['label'] = 17

n18 = pd.read_csv("../data/tracing-data/social-network/18_usertimeline_write_text.csv")
n18 = n18.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n18 = meanNorm(n18)
n18['label'] = 18

n19 = pd.read_csv("../data/tracing-data/social-network/19_redishashset_update_text.csv")
n19 = n19.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n19 = meanNorm(n19)
n19['label'] = 19

n20 = pd.read_csv("../data/tracing-data/social-network/20_poststorage_storepost_url.csv")
n20 = n20.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n20 = meanNorm(n20)
n20['label'] = 20

n21 = pd.read_csv("../data/tracing-data/social-network/21_usertimeline_write_url.csv")
n21 = n21.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n21 = meanNorm(n21)
n21['label'] = 21

n22 = pd.read_csv("../data/tracing-data/social-network/22_redishashset_update_url.csv")
n22 = n22.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n22 = meanNorm(n22)
n22['label'] = 22

n23 = pd.read_csv("../data/tracing-data/social-network/23_poststorage_storepost_user.csv")
n23 = n23.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n23 = meanNorm(n23)
n23['label'] = 23

n24 = pd.read_csv("../data/tracing-data/social-network/24_usertimeline_write_user.csv")
n24 = n24.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n24 = meanNorm(n24)
n24['label'] = 24

n25 = pd.read_csv("../data/tracing-data/social-network/25_redishashset_update_user.csv")
n25 = n25.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n25 = meanNorm(n25)
n25['label'] = 25

n26 = pd.read_csv("../data/tracing-data/social-network/26_poststorage_storepost_uniqueid.csv")
n26 = n26.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n26 = meanNorm(n26)
n26['label'] = 26

n27 = pd.read_csv("../data/tracing-data/social-network/27_usertimeline_write_uniqueid.csv")
n27 = n27.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n27 = meanNorm(n27)
n27['label'] = 27

n28 = pd.read_csv("../data/tracing-data/social-network/28_redishashset_update_uniqueid.csv")
n28 = n28.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n28 = meanNorm(n28)
n28['label'] = 28

n29 = pd.read_csv("../data/tracing-data/social-network/29_poststorage_storepost_mention.csv")
n29 = n29.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n29 = meanNorm(n29)
n29['label'] = 29

n30 = pd.read_csv("../data/tracing-data/social-network/30_usertimeline_write_mention.csv")
n30 = n30.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n30 = meanNorm(n30)
n30['label'] = 30

n31 = pd.read_csv("../data/tracing-data/social-network/31_redishashset_update_mention.csv")
n31 = n31.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n31 = meanNorm(n31)
n31['label'] = 31

n32 = pd.read_csv("../data/tracing-data/social-network/no-interference.csv")
n32 = n32.loc[:, ["1_nginx_compose-post", "2_mediaservice_upload", "3_userservice_upload", "4_textservice_upload", "5_uniqueid_upload",
                "6_composepost_uploadmedia", "7_composepost_uploadcreator", "8_urlservice_upload", "9_usermentionservice_upload",
                "10_composepost_uploadtext", "11_composepost_uploaduniqueid", "12_composepost_uploadurl", "13_composepost_uploadusermention",
                "14_poststorage_storepost_media", "15_usertimeline_write_media", "16_redishashset_update_media", "17_poststorage_storepost_text",
                "18_usertimeline_write_text", "19_redishashset_update_text", "20_poststorage_storepost_url", "21_usertimeline_write_url",
                "22_redishashset_update_url", "23_poststorage_storepost_user", "24_usertimeline_write_user", "25_redishashset_update_user",
                "26_poststorage_storepost_uniqueid", "27_usertimeline_write_uniqueid", "28_redishashset_update_uniqueid", 
                "29_poststorage_storepost_mention", "30_usertimeline_write_mention", "31_redishashset_update_mention"]]
n32 = meanNorm(n32)
n32['label'] = -1

# %%
dat = pd.concat([n1, n2, n3, n4, n5, n6, n7, n8, n9, n10, n11, n12,
                 n13, n14, n15, n16, n17, n18, n19, n20, n21, n22, n23, n24, n25,
                 n26, n27, n28, n29, n30, n31, n32])
print(dat.shape)

filehandler = open("../data/full_data/social_network.pkl","wb")
pickle.dump(dat, filehandler)
filehandler.close()
tot_rows = dat.shape[0]
# Out:
# (25280000, 32)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-26-9909e6c4ee1c> in <module>
#       5
#       6 filehandler = open("../data/full_data/social_network.pkl","wb")
# ----> 7 pickle.dump(dat, filehandler)
#       8 filehandler.close()
#       9 tot_rows = dat.shape[0]
#
# MemoryError:

# %%
n1_sample = n1.sample(n = int(n1.shape[0]*sample_rows/tot_rows))
n2_sample = n2.sample(n = int(n2.shape[0]*sample_rows/tot_rows))
n3_sample = n3.sample(n = int(n3.shape[0]*sample_rows/tot_rows))
n4_sample = n4.sample(n = int(n4.shape[0]*sample_rows/tot_rows))
n5_sample = n5.sample(n = int(n5.shape[0]*sample_rows/tot_rows))
n6_sample = n6.sample(n = int(n6.shape[0]*sample_rows/tot_rows))
n7_sample = n7.sample(n = int(n7.shape[0]*sample_rows/tot_rows))
n8_sample = n8.sample(n = int(n8.shape[0]*sample_rows/tot_rows))
n9_sample = n9.sample(n = int(n9.shape[0]*sample_rows/tot_rows))
n10_sample = n10.sample(n = int(n10.shape[0]*sample_rows/tot_rows))
n11_sample = n11.sample(n = int(n11.shape[0]*sample_rows/tot_rows))
n12_sample = n12.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n13_sample = n13.sample(n = int(n10.shape[0]*sample_rows/tot_rows))
n14_sample = n14.sample(n = int(n11.shape[0]*sample_rows/tot_rows))
n15_sample = n15.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n16_sample = n16.sample(n = int(n11.shape[0]*sample_rows/tot_rows))
n17_sample = n17.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n18_sample = n18.sample(n = int(n10.shape[0]*sample_rows/tot_rows))
n19_sample = n19.sample(n = int(n11.shape[0]*sample_rows/tot_rows))
n20_sample = n20.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n21_sample = n21.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n22_sample = n22.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n23_sample = n23.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n24_sample = n24.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n25_sample = n25.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n26_sample = n26.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n27_sample = n27.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n28_sample = n28.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n29_sample = n29.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n30_sample = n30.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n31_sample = n31.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n32_sample = n32.sample(n = int(n12.shape[0]*sample_rows/tot_rows))

dat_sample = pd.concat([n1_sample, n2_sample, n3_sample, n4_sample, n5_sample,
                       n6_sample, n7_sample, n8_sample, n9_sample, n10_sample, n11_sample, n12_sample, 
                       n13_sample, n14_sample, n15_sample, n16_sample, n17_sample, n18_sample,
                       n19_sample, n20_sample, n21_sample, n22_sample, n23_sample, n24_sample, n25_sample,
                       n26_sample, n27_sample, n28_sample, n29_sample, n30_sample, n31_sample, n32_sample])
print(dat_sample.shape)

# %%
filehandler = open("../data/sample_data/social_network_sample.pkl","wb")
pickle.dump(dat_sample, filehandler)
filehandler.close()

# %%
dat = pd.concat([n1, n2, n3, n4, n5, n6, n7, n8, n9, n10, n11, n12,
                 n13, n14, n15, n16, n17, n18, n19, n20, n21, n22, n23, n24, n25,
                 n26, n27, n28, n29, n30, n31])
print(dat.shape)

filehandler = open("../data/full_data/social_network_only_bottlenecks.pkl","wb")
pickle.dump(dat, filehandler)
filehandler.close()
tot_rows = dat.shape[0]

# %%
n1_sample = n1.sample(n = int(n1.shape[0]*sample_rows/tot_rows))
n2_sample = n2.sample(n = int(n2.shape[0]*sample_rows/tot_rows))
n3_sample = n3.sample(n = int(n3.shape[0]*sample_rows/tot_rows))
n4_sample = n4.sample(n = int(n4.shape[0]*sample_rows/tot_rows))
n5_sample = n5.sample(n = int(n5.shape[0]*sample_rows/tot_rows))
n6_sample = n6.sample(n = int(n6.shape[0]*sample_rows/tot_rows))
n7_sample = n7.sample(n = int(n7.shape[0]*sample_rows/tot_rows))
n8_sample = n8.sample(n = int(n8.shape[0]*sample_rows/tot_rows))
n9_sample = n9.sample(n = int(n9.shape[0]*sample_rows/tot_rows))
n10_sample = n10.sample(n = int(n10.shape[0]*sample_rows/tot_rows))
n11_sample = n11.sample(n = int(n11.shape[0]*sample_rows/tot_rows))
n12_sample = n12.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n13_sample = n13.sample(n = int(n10.shape[0]*sample_rows/tot_rows))
n14_sample = n14.sample(n = int(n11.shape[0]*sample_rows/tot_rows))
n15_sample = n15.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n16_sample = n16.sample(n = int(n11.shape[0]*sample_rows/tot_rows))
n17_sample = n17.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n18_sample = n18.sample(n = int(n10.shape[0]*sample_rows/tot_rows))
n19_sample = n19.sample(n = int(n11.shape[0]*sample_rows/tot_rows))
n20_sample = n20.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n21_sample = n21.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n22_sample = n22.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n23_sample = n23.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n24_sample = n24.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n25_sample = n25.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n26_sample = n26.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n27_sample = n27.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n28_sample = n28.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n29_sample = n29.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n30_sample = n30.sample(n = int(n12.shape[0]*sample_rows/tot_rows))
n31_sample = n31.sample(n = int(n12.shape[0]*sample_rows/tot_rows))


dat_sample = pd.concat([n1_sample, n2_sample, n3_sample, n4_sample, n5_sample,
                       n6_sample, n7_sample, n8_sample, n9_sample, n10_sample, n11_sample, n12_sample, 
                       n13_sample, n14_sample, n15_sample, n16_sample, n17_sample, n18_sample,
                       n19_sample, n20_sample, n21_sample, n22_sample, n23_sample, n24_sample, n25_sample,
                       n26_sample, n27_sample, n28_sample, n29_sample, n30_sample, n31_sample])
print(dat_sample.shape)

# %%
filehandler = open("../data/sample_data/social_network_only_bottlenecks_sample.pkl","wb")
pickle.dump(dat_sample, filehandler)
filehandler.close()
